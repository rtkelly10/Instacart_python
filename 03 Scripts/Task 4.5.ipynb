# %% [markdown]
# ##### Data Consistency Checks Within Exercise

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#Import data set
path = r'C:\Users\rtkel\Documents\Data Analytics Course\Instacart Basket Analysis'

# %%
#Import products.csv
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '4.3_orders_products','products.csv'), index_col = False)

# %%
#Import data set wrangled
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = False)

# %%
#Create a dataframe
df_test = pd.DataFrame()

# %%
#Create a mixed type column
df_test['mix'] = ['a', 'b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
#check for mixed types
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col)
# Out:
# mix

# %%
#Changing data tyoe to string
df_test['mix'] = df_test['mix'].astype('str')

# %%
#Recheck for mixed data type
for col in df_test.columns.tolist():
  weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_test[weird]) > 0:
    print (col, ' mixed')
  else: print (col, ' consistent')
# Out:
# mix  consistent

# %%
#Find missing values
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# create subset of datatype
df_nan = df_prods[df_prods["product_name"].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
#Check for number of rows in product dataframe
df_prods.shape
# Out:
# (49693, 5)

# %%
#Create a datafram for non missing value
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
#Compare row and colmumns of dataframe
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#Check for mixed type data after filtering missing values
for col in df_prods_clean.columns.tolist():
  weird = (df_prods_clean[[col]].applymap(type) != df_prods_clean[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_prods_clean[weird]) > 0:
    print (col)

# %%
#Find duplicates within dataframe
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
#check for number of rows in df_prods_clean
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
#Create a new dataframe that doesnt include duplocates
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
#check for number of rows in df_prods_clean_no_dups data frame
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# ##### Step 2

# %%
#Run describe function on df_ords
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week  hour_of_order  days_since_prior_order
# count        3.421083e+06   3.421083e+06            3.214874e+06
# mean         2.776219e+00   1.345202e+01            1.111484e+01
# std          2.046829e+00   4.226088e+00            9.206737e+00
# min          0.000000e+00   0.000000e+00            0.000000e+00
# 25%          1.000000e+00   1.000000e+01            4.000000e+00
# ...

# %% [markdown]
# Answer: I cannot find anything that looks inconsitent or off for this dataset.

# %% [markdown]
# ##### Step 3

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    hour_of_order  days_since_prior_order
# 0              8                     NaN
# 1              7                    15.0
# 2             12                    21.0
# 3              7                    29.0
# 4             15                    28.0

# %%
#checking for mixed data types
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col, ' mixed')
  else: print (col, ' consistent')
# Out:
# Unnamed: 0  consistent
# order_id  consistent
# user_id  consistent
# eval_set  consistent
# order_number  consistent
# orders_day_of_week  consistent
# hour_of_order  consistent
# days_since_prior_order  consistent

# %% [markdown]
# No mixed data found.

# %% [markdown]
# ##### Step 4

# %% [markdown]
# No mixed data found in df_ords.

# %% [markdown]
# ##### Step 5

# %%
#check for missing values in df_ords data frame
df_ords.isnull().sum()
# Out:
# Unnamed: 0                     0
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# hour_of_order                  0
# days_since_prior_order    206209
# dtype: int64

# %%
#Create subset for missing values in df_ords
df_ords_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
#View new missing values data frame

df_ords_nan
# Out:
#          Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0                 0   2539329        1    prior             1
# 11               11   2168274        2    prior             1
# 26               26   1374495        3    prior             1
# 39               39   3343014        4    prior             1
# 45               45   2717275        5    prior             1
# ...             ...       ...      ...      ...           ...
# 3420930     3420930    969311   206205    prior             1
# 3420934     3420934   3189322   206206    prior             1
# 3421002     3421002   2166133   206207    prior             1
# 3421019     3421019   2227043   206208    prior             1
# 3421069     3421069   3154581   206209    prior             1
#
#          orders_day_of_week  hour_of_order  days_since_prior_order
# 0                         2              8                     NaN
# 11                        2             11                     NaN
# ...

# %%
df_ords[df_ords['user_id'] == 1]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0            0   2539329        1    prior             1                   2
# 1            1   2398795        1    prior             2                   3
# 2            2    473747        1    prior             3                   3
# 3            3   2254736        1    prior             4                   4
# 4            4    431534        1    prior             5                   4
# 5            5   3367565        1    prior             6                   2
# 6            6    550135        1    prior             7                   1
# 7            7   3108588        1    prior             8                   1
# 8            8   2295261        1    prior             9                   1
# 9            9   2550362        1    prior            10                   4
# 10          10   1187899        1    train            11                   4
#
#     hour_of_order  days_since_prior_order
# ...

# %%
df_ords[df_ords['user_id'] == 2]
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 11          11   2168274        2    prior             1                   2
# 12          12   1501582        2    prior             2                   5
# 13          13   1901567        2    prior             3                   1
# 14          14    738281        2    prior             4                   2
# 15          15   1673511        2    prior             5                   3
# 16          16   1199898        2    prior             6                   2
# 17          17   3194192        2    prior             7                   2
# 18          18    788338        2    prior             8                   1
# 19          19   1718559        2    prior             9                   2
# 20          20   1447487        2    prior            10                   1
# 21          21   1402090        2    prior            11                   1
# ...

# %% [markdown]
# The two outputs above indicate that order number 1 or the first order has "NaN" for days_since_prior_order which makes sense as there would be no prior orders before the first.

# %% [markdown]
# ##### Step 6

# %% [markdown]
# As the missing values have a logical explanation it is unnecessary to remove the values.

# %% [markdown]
# ##### Step 7

# %%
# check for duplicate values in df_ords
df_ords_dups = df_ords[df_ords.duplicated()]

# %%
#view duplicate values
df_ords_dups
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, order_id, user_id, eval_set, order_number, orders_day_of_week, hour_of_order, days_since_prior_order]
# Index: []

# %% [markdown]
# Zero duplicates found.

# %% [markdown]
# ##### Step 8

# %% [markdown]
# Zero duplicates found.

# %% [markdown]
# ##### Step 9

# %%
#export df_ords as df_ords_cleaned
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_ords_cleaned.csv'))

# %%
#export df_prods as df_prods_cleaned
df_prods.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_prods_cleaned.csv'))
